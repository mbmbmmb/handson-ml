# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/13_gpt2_block.ipynb)
#
# # 🔴 Hard: GPT-2 Transformer Block
#
# Implement a full **GPT-2 style Transformer block** — combining everything you've learned.
#
# ### Architecture (Pre-Norm)
# ```
# x = x + causal_self_attention(ln1(x))
# x = x + mlp(ln2(x))
# ```
#
# ### Signature
# ```python
# class GPT2Block(nn.Module):
#     def __init__(self, d_model: int, num_heads: int): ...
#     def forward(self, x: torch.Tensor) -> torch.Tensor: ...
# ```
#
# ### Requirements
# - Inherit from `nn.Module`
# - `self.ln1`, `self.ln2`: `nn.LayerNorm(d_model)`
# - `self.W_q`, `self.W_k`, `self.W_v`, `self.W_o`: `nn.Linear` for attention
# - `self.mlp`: `nn.Sequential(Linear(d, 4d), GELU(), Linear(4d, d))`
# - Attention must be **causal** (mask future positions)
# - Pre-norm architecture (LayerNorm *before* attention and MLP)
# - Residual connections around both attention and MLP

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.2 MB/s eta 0:00:00

# %%
import torch
import torch.nn as nn
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class GPT2Block(nn.Module):
    def __init__(self, d_model, num_heads):
        super().__init__()
        # pass  # Initialize layers
        self.ln1 = nn.LayerNorm(d_model)
        self.ln2 = nn.LayerNorm(d_model)

        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)
        self.d_k = d_model // num_heads
        self.num_heads = num_heads
        self.d_model = d_model

        self.mlp = nn.Sequential(nn.Linear(d_model, 4*d_model), nn.GELU(), nn.Linear(4*d_model, d_model))
    def causal_att(self, x):
        # x (B, T, dmodel)
        Q = self.W_q(x).view(x.shape[0], x.shape[1], self.num_heads, self.d_k).transpose(1, 2)
        K = self.W_k(x).view(x.shape[0], x.shape[1], self.num_heads, self.d_k).transpose(1, 2)
        V = self.W_v(x).view(x.shape[0], x.shape[1], self.num_heads, self.d_k).transpose(1, 2)
        # (B, num_heads, T, d_k)
        #torch.bmm strictly requires 3D inputs
         #(batch_size, sequence_length, features)
        score = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_k)
        # (B, num_heads, T, T)
        mask = torch.ones_like(score).triu(diagonal = 1).bool()
        # print(mask)
        score = score.masked_fill(mask, -float('inf'))
        # print(score)
        att_w = torch.softmax(score, dim = -1)
        output = torch.matmul(att_w, V).transpose(1, 2)
        output = output.reshape(x.shape)
        # (B, num_heads, T, d_k)
        # print(output.shape, x.shape)
        return self.W_o(output)
    def forward(self, x):
        # pass  # Pre-norm + causal attention + MLP with residuals
        # x (B, T, dmodel)
        x = x + self.causal_att(self.ln1(x))
        x = x + self.mlp(self.ln2(x))
        return x

# %%
# 🧪 Debug
torch.manual_seed(0)
block = GPT2Block(d_model=64, num_heads=4)
x = torch.randn(2, 8, 64)
out = block(x)
print("Output shape:", out.shape)           # (2, 8, 64)
print("Is nn.Module?", isinstance(block, nn.Module))
print("Params:", sum(p.numel() for p in block.parameters()))
# Out:
# Output shape: torch.Size([2, 8, 64])
# Is nn.Module? True
# Params: 49984

# %%
from torch_judge import check
check('gpt2_block')
# Out:
# 🧪 Testing: GPT-2 Transformer Block (Hard)
# ──────────────────────────────────────────────────
#   ✅ [1/5] Output shape (48.9ms)
#   ✅ [2/5] Has LayerNorm (pre-norm architecture) (22.7ms)
#   ✅ [3/5] MLP has 4x expansion with GELU (10.4ms)
#   ✅ [4/5] Causal masking — future doesn't affect past (73.5ms)
#   ✅ [5/5] Gradient flow to all parameters (20.6ms)
# ──────────────────────────────────────────────────
#   🎉 All 5 tests passed! (176.1ms total)
#   Progress saved. Run status() to see your dashboard.
